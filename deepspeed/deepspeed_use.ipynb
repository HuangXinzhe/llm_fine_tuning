# %%
# %cd /content/drive/MyDrive/deepspeed
# Out:
# /content/drive/MyDrive/deepspeed

# %%
# !pwd
# Out:
# /content/drive/MyDrive/deepspeed

# %%
# !CUDA_VISIVLE_DEVICES=0 python -c "import torch; print(torch.cuda.get_device_capability())"
# Out:
# (7, 5)

# %%
# !python -c "import torch; print(torch.cuda.get_arch_list())"
# Out:
# ['sm_50', 'sm_60', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90']

# %%
# !CUDA_VISIVLE_DEVICES=0 python -c "import torch; print(torch.cuda.get_device_properties(torch.device('cuda')))"
# Out:
# _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15102MB, multi_processor_count=40)

# %%
# !pip install ninja
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 2.7 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/microsoft/DeepSpeed/
# Out:
# Cloning into 'DeepSpeed'...
# remote: Enumerating objects: 43602, done.
# remote: Counting objects: 100% (7112/7112), done.
# remote: Compressing objects: 100% (788/788), done.
# remote: Total 43602 (delta 6658), reused 6543 (delta 6295), pack-reused 36490
# Receiving objects: 100% (43602/43602), 207.19 MiB | 18.02 MiB/s, done.
# Resolving deltas: 100% (31461/31461), done.
# Updating files: 100% (1531/1531), done.

# %%
# %cd DeepSpeed
# Out:
# /content/drive/MyDrive/deepspeed/DeepSpeed

# %%
# !rm -rf build

# %%
# !TORCH_CUDA_ARCH_LIST="7.5" DS_BUILD_CPU_ADAM=1 DS_BUILD_UTILS=1 pip install . \
--global-option="build_ext" --global-option="-j8" --no-cache -v \
--disable-pip-version-check 2>&1 | tee build.log
# Out:
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# DEPRECATION: --build-option and --global-option are deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use --config-settings. Discussion can be found at https://github.com/pypa/pip/issues/11859
# WARNING: Implying --no-binary=:all: due to the presence of --build-option / --global-option.
# Processing /content/drive/MyDrive/deepspeed/DeepSpeed
#   Preparing metadata (setup.py): started
#   Running command python setup.py egg_info
#   [2024-03-11 14:57:18,177] [INFO] [real_accelerator.py:191:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#   [2024-03-11 14:57:20,487] [INFO] [real_accelerator.py:191:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#   DS_BUILD_OPS=0
#    [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#    [WARNING]  async_io: please install the libaio-dev package with apt
# ...

# %%
# %cd /content/drive/MyDrive/deepspeed
# Out:
# /content/drive/MyDrive/deepspeed

# %%
# !deepspeed --num_gpus=1 translation/run_translation.py \
--deepspeed config/ds_config_zero2.json \
--model_name_or_path t5-small --per_device_train_batch_size 1 \
--output_dir output_dir --overwrite_output_dir --fp16 \
--do_train --max_train_samples 500 --num_train_epochs 1 \
--dataset_name wmt16 --dataset_config "ro-en" \
--source_lang en --target_lang ro
# Out:
# [2024-03-11 14:58:41,058] [INFO] [real_accelerator.py:191:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [2024-03-11 14:58:43,569] [WARNING] [runner.py:202:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2024-03-11 14:58:43,569] [INFO] [runner.py:568:main] cmd = /usr/bin/python3 -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMF19 --master_addr=127.0.0.1 --master_port=29500 --enable_each_rank_log=None translation/run_translation.py --deepspeed config/ds_config_zero2.json --model_name_or_path t5-small --per_device_train_batch_size 1 --output_dir output_dir --overwrite_output_dir --fp16 --do_train --max_train_samples 500 --num_train_epochs 1 --dataset_name wmt16 --dataset_config ro-en --source_lang en --target_lang ro
# [2024-03-11 14:58:46,936] [INFO] [real_accelerator.py:191:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# ...
